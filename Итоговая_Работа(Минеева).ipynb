# %% [markdown]
# <a href="https://colab.research.google.com/github/lubamin14/-/blob/main/%D0%98%D1%82%D0%BE%D0%B3%D0%BE%D0%B2%D0%B0%D1%8F_%D0%A0%D0%B0%D0%B1%D0%BE%D1%82%D0%B0(%D0%9C%D0%B8%D0%BD%D0%B5%D0%B5%D0%B2%D0%B0).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **<center> ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ</center>**
# **<center>ГОРОДА МОСКВЫ</center>**
# **<center>ДОПОЛНИТЕЛЬНОГО ПРОФЕССИОНАЛЬНОГО ОБРАЗОВАНИЯ</center>**
# **<center>ЦЕНТР ПРОФЕССИОНАЛЬНЫХ КВАЛИФИКАЦИЙ И СОДЕЙСТВИЯ ТРУДОУСТРОЙСТВУ</center>**
# **<center>«ПРОФЕССИОНАЛ»</center>**
# <br>
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <center> ИТОГОВАЯ АТТЕСТАЦИОННАЯ РАБОТА </center>
# <center> на тему </center>
# <center> «Анализ данных с использованием Python» </center>
# <center> (на примере анализа данных исследуемого продукта) </center>
# <center>слушателя Минеевой Любовь Борисовны<br>группы № 287-гз </center>
#  <center>по программе профессиональной переподготовки </center>
# <center> «Python для анализа данных» </center>
# <br>
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <center> Москва, 2024

# %% [markdown]
# ### Цель исследования:

# %% [markdown]
# Цель данного проекта — выявить, какие признаки имеют наибольшее влияние на рейтинг вина, составляемого специализированным журналом Wine Enthusiast. Для анализа используется набор данных из Kaggle (профессиональное сообщество специалистов по обработке данных и машинному обучению). Датафрейм состоит из 13 признаков (2 числовых признака и 11 категориальных признаков).
#
# Анализ данных предполагает последовательное выполнение следующих этапов исследования:<br>
# <a href=#1>1.  Предобработка данных</a><br>
# <a href=#2>2.  Исследовательский анализ данных</a><br>
# <a href=#3>3.  Составление структуры развития рынка вина каждого региона</a><br>
# <a href=#4>4.  Проведение исследования статистических показателей зависимости цены вина от рейтинга в регионе</a><br>
# <a href=#5>5.  Проверка гипотез</a><br>
# <a href=#6>6.  Выводы</a><br>

# %% [markdown]
# ### Столбцы данных
# - Страна - страна происхождения вина.<br>
# - Описание — описание вкусового профиля вина.<br>
# - Обозначение - виноградник-поставщик винограда для изготовления вина.<br>
# - Рейтинг - оценка вина специализированным журналом Wine Enthusiast, выраженная в баллах по шкале от 1 до 100.<br>
# - Цена - цена одной бутылки вина.<br>
# - Провинция — регион (провинция, штат) производства вина.<br>
# - Регион 1 — зона виноделия в регионе (например, долина Напа в Калифорнии). <br>
# - Регион 2 — (необязательно) терруар виноделия - более конкретная область в винодельческом регионе (например, Резерфорд в долине Напа).<br>
# - Разновидность — сорт винограда, используемый в производстве вина (например, Пино Нуар).<br>
# - Винодельня — производитель вина.<br>

# %% [markdown]
# #  <a name="1">1.Предобработка данных</a>

# %% [markdown]
# Подготовка данных к анализу (очистка данных, трансформация данных, дополнение, оптимизация):
# * Заменить названия столбцов (привести к нижнему регистру).<br>
# * Преобразовать данные в нужные типы. Описать, в каких столбцах заменили тип данных и почему.<br>
# * Обработать пропуски при необходимости. <br>
# * Внести новый столбец "Континенты" в случае необходимости<br> country_to_continent = {<br>
# 'Italy':'Europe',<br>
# 'Portugal':'Europe',<br>
# 'US':'North America',<br>
# 'Spain':'Europe',<br>
# 'France':'Europe',<br>
# 'Germany':'Europe',<br>
# 'Argentina':'Latin America',<br>
# 'Chile':'Latin America',<br>
# 'Australia': 'Oceania',<br>
# 'Austria': 'Europe',<br>
# 'South Africa': 'Africa',<br>
# 'New Zealand': 'Oceania',<br>
# 'Israel': 'Asia', <br>
# 'Hungary':'Europe',<br>
# 'Greece':'Europe',<br>
# 'Romania':'Europe',<br>
# 'Mexico':'Latin America',<br>
# 'Canada':'North America',<br>
# 'Turkey': 'Asia',<br>
# 'Czech Republic': 'Europe',<br>
# 'Slovenia': 'Europe',<br>
# 'Luxembourg': 'Europe',<br>
# 'Croatia': 'Europe',<br>
# 'Georgia':'Europe',<br>
# 'Uruguay': 'Latin America',<br>
# 'England': 'Europe',<br>
# 'Lebanon': 'Asia',<br>
# 'Serbia': 'Europe',<br>
# 'Brazil': 'Latin America',<br>
# 'Moldova': 'Europe',<br>
# 'Morocco':'Africa',<br>
# 'Peru':'Latin America',<br>
# 'India':'Asia',<br>
# 'Bulgaria':'Europe',<br>
# 'Cyprus': 'Europe',<br>
# 'Armenia':'Asia',<br>
# 'Switzerland':'Europe',<br>
# 'Bosnia and Herzegovina':'Europe',<br>
# 'Ukraine':'Europe',<br>
# 'Slovakia':'Europe',<br>
# 'Macedonia':'Europe',<br>
# 'China':'Asia',<br>
# 'Egypt':'Africa'<br>
# }

# %% [markdown]
# Импорт необходимых библиотек

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm

import scipy.stats as st
# импорт библиотеки warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# Загрузка данных

# %%
df = pd.read_csv('https://drive.google.com/uc?id=1mjBaWTQopVQzhVOj3oRw4g8UYz9AeK6x')
df.head(5)
# Out:
#   country                                        description designation  \
# 0      US  With a delicate, silky mouthfeel and bright ac...         NaN
# 1   Italy  D'Alceo is a drop dead gorgeous wine that ooze...     D'Alceo
# 2  France  The great dominance of Cabernet Sauvignon in t...         NaN
# 3   Italy  The modest cherry, dark berry and black tea no...         NaN
# 4      US  Exceedingly light in color, scent and flavor, ...         NaN
#
#    points  price    province          region_1         region_2  \
# 0      86   23.0  California     Central Coast    Central Coast
# 1      96  275.0     Tuscany           Toscana              NaN
# 2      91   40.0    Bordeaux        Haut-Médoc              NaN
# 3      81   15.0     Tuscany  Chianti Classico              NaN
# 4      83   25.0      Oregon      Rogue Valley  Southern Oregon
#
#                     variety                 winery
# 0                Pinot Noir        MacMurray Ranch
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      20000 non-null  object
#  1   description  20000 non-null  object
#  2   designation  13999 non-null  object
#  3   points       20000 non-null  int64
#  4   price        18198 non-null  float64
#  5   province     20000 non-null  object
#  6   region_1     16543 non-null  object
#  7   region_2     8058 non-null   object
#  8   variety      20000 non-null  object
#  9   winery       20000 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.5+ MB

# %% [markdown]
# Количество значений в столбцах различается. Это говорит о том, что в данных есть пустые значения. Признак points и price числовые. С помощью библиотеки Seaborn построим тепловую карту для визуализации данных.

# %%
colours = ['#993366', '#FFFF00']
sns.heatmap(df.isnull(), cmap=sns.color_palette(colours))
# Decorations
plt.title('Матрица пропущенных значений набора данных', fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=12)
plt.figtext(0.5, -0.2, "Рисунок 1. - Матрица пропущенных значений набора данных")
plt.show()

# %% [markdown]
# Приведем названия столбцов к нижнему регистру.

# %%
# Приведение названий столбцов к нижнему регистру
df.columns = df.columns.str.lower()

# %% [markdown]
# Посчитаем количество пропущенных значений в каждой переменной.

# %%
print(df.isnull().sum())
# Out:
# country            0
# description        0
# designation     6001
# points             0
# price           1802
# province           0
# region_1        3457
# region_2       11942
# variety            0
# winery             0
# dtype: int64

# %%
MissingValue = df.isnull().sum().sort_values(ascending = False)
Percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)
MissingData = pd.concat([MissingValue, Percent], axis=1, keys=['MissingValue', 'Percent'])
MissingData
# Out:
#              MissingValue  Percent
# region_2            11942   59.710
# designation          6001   30.005
# region_1             3457   17.285
# price                1802    9.010
# country                 0    0.000
# description             0    0.000
# points                  0    0.000
# province                0    0.000
# variety                 0    0.000
# winery                  0    0.000

# %% [markdown]
# Поля region_2 не заполнен более чам на 50 %, удалим этот признак. Так как он не информативен.

# %%
# Drops unnecessary columns
df = df.drop(columns = ["region_2"])

# %% [markdown]
# Удалим пустые строки с ценами

# %%
total_records = len(df)
missing_prices = df["price"].isnull().sum()
missing_ratio = 100 - ((missing_prices / total_records) * 100)
print("Количество рпопущеных значений: {}".format(missing_prices)+ "\n" +
      "Всего записей: {}".format(total_records) + "\n" +
      "Процентное соотношение после удаления столбцов: {:.2f}%".format(missing_ratio))
# Out:
# Количество рпопущеных значений: 1802
# Всего записей: 20000
# Процентное соотношение после удаления столбцов: 90.99%

# %% [markdown]
# Если мы удалим все записи с отсутствующими ценами, мы останемся с 90,99% набора данных. Мы можем смело отбрасывать записи с отсутствующими значениями и не влиять на результаты кардинально.

# %%
df = df.dropna(axis='index', how='any', subset=['price'])
print(df.count())
# Out:
# country        18198
# description    18198
# designation    12637
# points         18198
# price          18198
# province       18198
# region_1       15033
# region_2        8019
# variety        18198
# winery         18198
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# country            0
# description        0
# designation     5561
# points             0
# price              0
# province           0
# region_1        3165
# region_2       10179
# variety            0
# winery             0
# dtype: int64

# %% [markdown]
# Оставим region_1 и designation без изменения

# %% [markdown]
# Добавим столбец цвет вина

# %%
color = {
"Chardonnay": "white",
"Pinot Noir": "red",
"Cabernet Sauvignon": "red",
"Red Blend": "red",
"Bordeaux-style Red Blend": "red",
"Sauvignon Blanc": "white",
"Syrah": "red",
"Riesling": "white",
"Merlot": "red",
"Zinfandel": "red",
"Sangiovese": "red",
"Malbec": "red",
"White Blend": "white",
"Rosé": "other",
"Tempranillo": "red",
"Nebbiolo": "red",
"Portuguese Red": "red",
"Sparkling Blend": "other",
"Shiraz": "red",
"Corvina, Rondinella, Molinara": "red",
"Rhône-style Red Blend": "red",
"Barbera": "red",
"Pinot Gris": "white",
"Viognier": "white",
"Bordeaux-style White Blend": "white",
"Champagne Blend": "other",
"Port": "red",
"Grüner Veltliner": "white",
"Gewürztraminer": "white",
"Portuguese White": "white",
"Petite Sirah": "red",
"Carmenère": "red"
}
df['color']= df['variety'].map(color)
df = df.dropna(axis='index', how='any', subset=['color'])
print(df.count())
# Out:
# country        15041
# description    15041
# designation    10526
# points         15041
# price          15041
# province       15041
# region_1       12365
# variety        15041
# winery         15041
# color          15041
# dtype: int64

# %%
#количество уникальных значений
df['color'].value_counts()
# Out:
# color
# red      9866
# white    4407
# other     768
# Name: count, dtype: int64

# %% [markdown]
# Удалим дубликаты

# %%
df=df.drop_duplicates(keep=False)
df.head()
# Out:
#   country                                        description designation  \
# 0      US  With a delicate, silky mouthfeel and bright ac...         NaN
# 1   Italy  D'Alceo is a drop dead gorgeous wine that ooze...     D'Alceo
# 2  France  The great dominance of Cabernet Sauvignon in t...         NaN
# 3   Italy  The modest cherry, dark berry and black tea no...         NaN
# 4      US  Exceedingly light in color, scent and flavor, ...         NaN
#
#    points  price    province          region_1         region_2  \
# 0      86   23.0  California     Central Coast    Central Coast
# 1      96  275.0     Tuscany           Toscana              NaN
# 2      91   40.0    Bordeaux        Haut-Médoc              NaN
# 3      81   15.0     Tuscany  Chianti Classico              NaN
# 4      83   25.0      Oregon      Rogue Valley  Southern Oregon
#
#                     variety                 winery
# 0                Pinot Noir        MacMurray Ranch
# ...

# %%
print(df.count())
# Out:
# country        16219
# description    16219
# designation    11243
# points         16219
# price          16219
# province       16219
# region_1       13407
# region_2        7128
# variety        16219
# winery         16219
# dtype: int64

# %% [markdown]
# *Добавим столбец континенты* (?)

# %%
# Comparing rating per continent

#creating dictionary for country and its continent
country_to_continent = {
    'Italy':'Europe',
    'Portugal':'Europe',
    'US':'North America',
    'Spain':'Europe',
    'France':'Europe',
    'Germany':'Europe',
    'Argentina':'Latin America',
    'Chile':'Latin America',
    'Australia': 'Oceania',
    'Austria': 'Europe',
    'South Africa': 'Africa',
    'New Zealand': 'Oceania',
    'Israel': 'Asia',
    'Hungary':'Europe',
    'Greece':'Europe',
    'Romania':'Europe',
    'Mexico':'Latin America',
    'Canada':'North America',
    'Turkey': 'Asia',
    'Czech Republic': 'Europe',
    'Slovenia': 'Europe',
    'Luxembourg': 'Europe',
    'Croatia': 'Europe',
    'Georgia':'Europe',
    'Uruguay': 'Latin America',
    'England': 'Europe',
    'Lebanon': 'Asia',
    'Serbia': 'Europe',
    'Brazil': 'Latin America',
    'Moldova': 'Europe',
    'Morocco':'Africa',
    'Peru':'Latin America',
    'India':'Asia',
    'Bulgaria':'Europe',
    'Cyprus': 'Europe',
    'Armenia':'Asia',
    'Switzerland':'Europe',
    'Bosnia and Herzegovina':'Europe',
    'Ukraine':'Europe',
    'Slovakia':'Europe',
    'Macedonia':'Europe',
    'China':'Asia',
    'Egypt':'Africa'
    }
# wine_df['country'].unique()
# type(country)

#adding column to put column from the country
df['continent'] =df['country'].map(country_to_continent)
df
# Out:
#             country                                        description  \
# 0                US  With a delicate, silky mouthfeel and bright ac...
# 1             Italy  D'Alceo is a drop dead gorgeous wine that ooze...
# 2            France  The great dominance of Cabernet Sauvignon in t...
# 3             Italy  The modest cherry, dark berry and black tea no...
# 4                US  Exceedingly light in color, scent and flavor, ...
# ...             ...                                                ...
# 19991  South Africa  Muscular spice, deep red berry and blackberry ...
# 19993        France  A beautifully elegant wine, wearing its fresh ...
# 19994            US  A little too strong in feline spray character,...
# 19996            US  The vineyard is on the Napa side of Carneros. ...
# 19999            US  Grown on the Sonoma side of the appellation, i...
#
#                  designation  points  price      province          region_1  \
# ...

# %%
df_continent = df['continent'].value_counts().to_frame()
df_continent.reset_index(inplace=True)
df_continent.columns = ['continent','counts']
fig, ax = plt.subplots(figsize=(10,6));
sns.barplot(data = df_continent, x='continent',y='counts',ax=ax).set_title('Количество образцов по каждой стране');
plt.figtext(0.4, -0.2, "Рисунок 2. - Распределение по странам ")
plt.xticks(rotation='vertical');

# %%
df_country = df['country'].value_counts().to_frame()
df_country.reset_index(inplace=True)
df_country.columns = ['country','counts']
fig, ax = plt.subplots(figsize=(10,6));
sns.barplot(data = df_country, x='country',y='counts',ax=ax).set_title('Количество образцов по каждой стране');
plt.figtext(0.4, -0.1, "Рисунок 2. - Распределение по странам ")
plt.xticks(rotation='vertical');

# %%
df_country = df['continent'].value_counts().to_frame()
df_country.reset_index(inplace=True)
df_country.columns = ['continent','counts']
fig, ax = plt.subplots(figsize=(10,6));
sns.barplot(data = df_country, x='continent',y='counts',ax=ax).set_title('Количество образцов по каждому континенту');
plt.figtext(0.4, -0.1, "Рисунок 3. - Распределение по континентам ")
plt.xticks(rotation='vertical');

# %% [markdown]
# Для данного набора данных лидиром среди континентов является Северная Америка.

# %% [markdown]
# ##Признак designation

# %%
df.designation.value_counts()
df.designation.value_counts()[:10]
# Out:
# designation
# Reserve           283
# Estate            182
# Reserva           175
# Estate Grown       53
# Riserva            50
# Estate Bottled     43
# Brut               39
# Old Vine           35
# Dry                34
# Gran Reserva       27
# Name: count, dtype: int64

# %% [markdown]
# ##Рейтинг (points)

# %%
df["points"].describe()
# Out:
# count    13388.000000
# mean        87.889080
# std          3.287479
# min         80.000000
# 25%         86.000000
# 50%         88.000000
# 75%         90.000000
# max        100.000000
# Name: points, dtype: float64

# %%
sns.histplot(df.points, kde=False)
plt.show()

# %% [markdown]
# Построим столбчатую диаграмму, иллюстрирующую количество вин в каждом рейтинговом балле

# %%
fig, ax = plt.subplots(figsize=(15,7))
plt.xlabel("Рейтинг")
plt.ylabel("Количество вина")
plt.title("Количество вина для каждого рейтинга")
df.groupby(['points']).count()['description'].plot(ax=ax, kind='bar')
plt.figtext(0.4, 0, "Рисунок 4. - Гистограмма частоты признака Points ")
plt.show()

# %%
fig = plt.figure(figsize=(18,12))
top_reviewed_wines = df.variety.value_counts().head(10)
points_top_reviewed_wines = df[df.variety.isin(top_reviewed_wines.index)]


sns.boxplot(x = points_top_reviewed_wines.variety,y = points_top_reviewed_wines.points)
plt.xlabel('Сорт винограда', fontsize=20)
plt.ylabel('Рейтинг', fontsize=20)
plt.title('Распределения рейтинга вина по топ 10 сортов винограда',fontsize=20)
plt.figtext(0.5, 0, "Рисунок 6. - Зависимость рейтинга от топ 10 популярных сортов винограда" )
# Out:
# Text(0.5, 0, 'Рисунок 6. - Зависимость рейтинга от топ 10 популярных сортов винограда')

# %%
df.loc[df.variety.isin(["Pinot Noir", "Cabernet Sauvignon","Red Blend","Bordeaux-style Red Blend", "Syrah", "Merlot","Zinfandel","Sangiovese","Malbec","Tempranillo",
"Nebbiolo","Portuguese Red","Shiraz","Corvina, Rondinella, Molinara","Rhône-style Red Blend","Barbera","Port","Petite Sirah","Carmenère"]), 'color'] = 'red'

# %%
df['color'].value_counts()
# Out:
# color
# red      8794
# white    3927
# other     667
# Name: count, dtype: int64

# %% [markdown]
# #  <a name="2"> 2. Исследовательский анализ данных</a>
# * Найти среднюю цену вина по региону.
# * Выбрать сорта с наибольшими ценами.
# * Найти среднюю цену вина для региона.
# * Определить, популярные сорта вина в бюджетном сегменте.
# * Определить, какие сорта вина лидируют по рейтингам.
# * Построить график «ящик с усами» по рейтингам в разбивке по странам, по сортам вина.
# * Выявить закономерность влияния на цену  цвета и рейтинга вина.
# * Построить диаграмму рассеяния и посчитать корреляцию.

# %% [markdown]
# ##2.1.Исследование цены вина

# %%
df['price'].describe()
# Out:
# count    13388.000000
# mean        34.804228
# std         42.989997
# min          5.000000
# 25%         16.000000
# 50%         25.000000
# 75%         41.000000
# max       2300.000000
# Name: price, dtype: float64

# %%
df.country.nunique()
# Out:
# 32

# %% [markdown]
# Всего представлены 33 страны. Выберем топ 10.

# %%
# Средняя цена вина по региону
average_price_by_country = df_selected.groupby('country')['price'].mean()
print(average_price_by_country)
# Out:
# country
# Austria    34.416667
# France     50.450770
# Italy      42.803704
# Spain      30.092421
# Name: price, dtype: float64

# %%
# Сорта с наибольшими ценами
highest_price_varieties = df_selected.loc[df_selected['price'] == df_selected['price'].max(), 'variety']
print(highest_price_varieties)
# Out:
# 13188    Bordeaux-style Red Blend
# Name: variety, dtype: object

# %%
# Средняя цена вина для региона (аналогично пункту 1)
average_price = df_selected['price'].mean()
print(average_price)
# Out:
# 43.56166666666667

# %% [markdown]
# ##Определить популярные сорта вина в бюджетном сегменте

# %%
# Предположим, что бюджетный сегмент - это вина с ценой ниже 10
popular_budget_varieties = df[df['price'] < 10]['variety'].value_counts().head(10)
print(popular_budget_varieties)
# Out:
# variety
# Chardonnay            62
# Sauvignon Blanc       48
# Merlot                47
# Cabernet Sauvignon    46
# Rosé                  29
# Portuguese Red        27
# White Blend           23
# Red Blend             23
# Tempranillo           22
# Portuguese White      22
# Name: count, dtype: int64

# %%
# Сорта с наивысшими рейтингами
top_rated_varieties = df.loc[df['points'] == df['points'].max(), 'variety']
print(top_rated_varieties)
# Out:
# 323     Chardonnay
# 5955        Merlot
# Name: variety, dtype: object

# %%
#Построить график «ящик с усами» по рейтингам в разбивке по странам и сортам вина
plt.figure(figsize=(12, 6))
sns.boxplot(x='country', y='points', data=df)
plt.title('Ящик с усами по рейтингам в разбивке по странам')
plt.xticks(rotation=45)
plt.show()

# %%
df.groupby('country').price.mean().plot(kind='box')
plt.xlabel('Рисунок 4. - Средняя цена вина по всем странам', fontsize=11);

# %%
fig = plt.figure()
sns.boxplot(x = df_selected.country, y = df_selected.price, palette='Set2')
plt.figtext(0.2, -0.1, 'рисунок 3. - Зависимость цен на вино от страны', fontsize=11);

# %%
fig = plt.figure()
sns.boxplot(x = df_selected.points, y = df_selected.price, palette='Set2')
plt.figtext(0.2, -0.1, 'рисунок 3. - Зависимость цен на вино от рейтинга', fontsize=11);

# %%
df.groupby('points').price.mean().plot(kind='box')
plt.xlabel('Рисунок 4. - Средняя цена вина по всем странам', fontsize=11);

# %%
# Расчет корреляции
correlation = df['points'].corr(df['price'])
print(f'Корреляция между рейтингами и ценами: {correlation}')
# Построение диаграммы рассеяния
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='price', y='points', alpha=0.6)
plt.title('Диаграмма рассеяния: Рейтинги vs Цены')
plt.xlabel('Цена')
plt.ylabel('Рейтинг')
plt.grid(True)
plt.show()
# Out:
# Корреляция между рейтингами и ценами: 0.4293769953324814

# %% [markdown]
# страны(country)

# %%
df["country"].describe()
# Out:
# count     20000
# unique       38
# top          US
# freq       8247
# Name: country, dtype: object

# %% [markdown]
# В наборе данных встречается 32 страны.Самая часта страна США  она встречается 6628 раз.

# %%
df_country = df['country'].value_counts().to_frame()
df_country.reset_index(inplace=True)
df_country.columns = ['country','counts']
fig, ax = plt.subplots(figsize=(15,10));
sns.barplot(data = df_country, x='country',y='counts',ax=ax).set_title('Количество образцов по каждой стране');
plt.figtext(0.4, -0.1, "Рисунок 2. - Распределение по странам ")
plt.xticks(rotation='vertical');

# %% [markdown]
# В наборе данных около 40% из них были из США, далее идет Франция, Италия, Чили. Такая тенденция может быть объяснена тем, что набор данных был подготовлоен журналом из США.

# %% [markdown]
# Выведем ТОП 10 наиболее часто встречающихся стран в наборе данных

# %%
countries_list = pd.DataFrame(df.country.value_counts(dropna = True)).iloc[0:10]
countries_list['Index'] = list(range(0,10))
countries_list['Country_Name'] = countries_list.index.values
countries_list.set_index('Index',inplace = True)
countries_list.columns = ['Number Of Wines Produced','Country']

countries_list
# Out:
#        Number Of Wines Produced      Country
# Index
# 0                          8247           US
# 1                          3092        Italy
# 2                          2751       France
# 3                          1090        Spain
# 4                           780        Chile
# 5                           751     Portugal
# 6                           734    Argentina
# 7                           622    Australia
# 8                           446  New Zealand
# 9                           419      Austria

# %% [markdown]
# ##средняя цена одной бутылки вина по региону

# %%
# Вычисление средней стоимости вина
average_price = df['price'].mean()
print("Средняя стоимость вина:", average_price)
# Out:
# Средняя стоимость вина: 33.20689086712826

# %%
avg_cost = df["price"].mean()
avg_cost
# Out:
# 33.20689086712826

# %% [markdown]
# #  <a name="3">3. Составление структуры развития рынка вина регионов</a>

# %% [markdown]
# * Самые популярные сорта (топ-5).
# * Влияет ли рейтинг на цены по регионам?

# %%
df['variety'].value_counts().head(5)
# Out:
# variety
# Pinot Noir                  1945
# Chardonnay                  1893
# Cabernet Sauvignon          1636
# Red Blend                   1329
# Bordeaux-style Red Blend     952
# Name: count, dtype: int64

# %% [markdown]
# #  <a name="4"> 4. Исследование статистических показателей зависимости цены вина от рейтинга в регионе.</a>

# %% [markdown]
# Построить линейную регрессию зависимости между ценой продукта и его рейтингом.

# %%
# Подготовка данных для линейной регрессии
x = df['price']
 # Предиктор: цена
y = df['points']

# %%
plt.scatter(x,y)
plt.ylabel('рейтинг')
plt.xlabel('цена')
# Out:
# Text(0.5, 0, 'цена')

# %% [markdown]
# #  <a name="5">5. Проверка гипотез </a>

# %% [markdown]
# * H0: Средние пользовательские рейтинги красного и белого вина одинаковые.
# * H1:Средние пользовательские рейтинги красного и белого вина разные.
#
# - Самостоятельно сформулировать и проверить гипотезу
#
#
# * Задать самостоятельно пороговое значение *alpha*.

# %%
Ho = "Рейтинг на вино производства Франции и на вино производства Италии одинаковы"   # Stating the Null Hypothesis
Ha = "Рейтинг на вино производства Франции и на вино производства Италии различны"   # Stating the Alternate Hypothesis
t = df[df.country == 'France']
g= df[df.country == 'Italy']
x = np.array(t[t.price < 200 ].points)  # Selecting charges corresponding to smokers as an array
y = np.array(g[g.price < 200].points) # Selecting charges corresponding to non-smokers as an array

# %%
from scipy import stats

# %%
results = stats.levene(x, y)

alpha = 0.05

print(results.pvalue)

if (results.pvalue < alpha):
    print('Отклонить гипотезу о равенстве дисперсий')
else:
    print('Принять гипотезу о равенстве дисперсий')
# Out:
# 9.115522697386737e-07
# Отклонить гипотезу о равенстве дисперсий

# %%
# Разделение данных на красное и белое вино
red_wine = df[df['color'] == 'red']['points']
white_wine = df[df['color'] == 'white']['points']

# %%
# Проведение t-теста
t_stat, p_value = stats.ttest_ind(red_wine, white_wine)

# Вывод результатов
print(f'T-статистика: {t_stat}')
print(f'P-значение: {p_value}')
# Out:
# T-статистика: 6.9173712961034
# P-значение: 4.796828489199676e-12

# %%
# Проверка нулевой гипотезы
if p_value < alpha:
    print('Отвергаем нулевую гипотезу (H0): Средние пользовательские рейтинги красного и белого вина разные.')
else:
    print('Не отвергаем нулевую гипотезу (H0): Средние пользовательские рейтинги красного и белого вина одинаковые.')
# Out:
# Отвергаем нулевую гипотезу (H0): Средние пользовательские рейтинги красного и белого вина разные.

# %%
t,p_value  = stats.ttest_ind(x,y, axis = 0, equal_var=False)

if p_value < 0.05:
    print(f'{Ha} так как p value - {p_value.round(3)} < 0.05')
else:
    print(f'{Ho} так как p value - {p_value.round(3)} > 0.05')
# Out:
# Рейтинг на вино производства Франции и на вино производства Италии одинаковы так как p value - 0.074 > 0.05

# %%
# Установка стиля графиков
sns.set(style="whitegrid")

# Построение графика
plt.figure(figsize=(12, 6))
sns.boxplot(x='color', y='points', data=df, palette='Set2')

# Добавление заголовка и меток
plt.title('Сравнение пользовательских рейтингов красного и белого вина')
plt.xlabel('Тип вина')
plt.ylabel('Пользовательский рейтинг')

# Показать график
plt.show()

# %% [markdown]
# # <a name="6">6. Выводы</a>

# %% [markdown]
# **<center>Список литературы</center>**

# %% [markdown]
# **Нормативные правовые акты:**
# 1.	Профессиональный стандарт «Специалист по большим данным» утверждён приказом Министерства труда и социальной защиты Российской Федерации от 6 июля 2020 г. № 405н.
#
# **Учебники и учебные пособия:**
# 1.	Андерсон. К., Аналитическая культура: от сбора данных до бизнес-результатов. - Москва : Манн, Иванов и Фербер, 2017.
# 2.	Нисчал Н., Python – это просто. Пошаговое руководство по программированию и анализу данных. — СПб.: БХВ-Петербург, 2021.
# 3.	Мэтиз Э., Изучаем Python. Программирование игр, визуализация данных, веб-приложения. — СПб.: Питер, 2021.
# 4.	Пасхавер Б., Pandas в действии. — СПб.: Питер, 2023.
# 5.	Плас Дж. Вандер., Python для сложных задач: наука о данных — СПб.: Питер, 2024.
# 6.	Уилке К., Основы визуализации данных. Пособие по эффективной и убедительной подаче информации.— М.: Эксмо, 2024.
#
# **Электронные ресурсы:**
# 1.	PEP 8 – руководство по стилю для кода Python [Электронный ресурс]: URL: https://peps.python.org/pep-0008/ ((дата обращения: 10.12.2024).
# 2.	Сайт Python Academy [Электронный ресурс]: URL: https://www.python-academy.com/ (дата обращения: 10.12.2024).
